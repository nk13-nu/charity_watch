# %%
import pandas as pd

# %%
df = pd.read_csv("../charity_watch_streamlit/data/charities_with_deprivation.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            299 non-null    int64
#  1   name                          299 non-null    object
#  2   address                       299 non-null    object
#  3   postcode                      299 non-null    object
#  4   constituency                  299 non-null    object
#  5   Last Recorded Financial Year  299 non-null    object
#  6   income                        299 non-null    float64
#  7   expenditure                   299 non-null    float64
#  8   howHelps                      299 non-null    object
#  9   whatDoes                      299 non-null    object
#  10  whoHelps                      294 non-null    object
#  11  activities                    299 non-null    object
# ...
