# %%
import geopandas as gpd

# %%
df = gpd.read_file('../data/final_data/lsoa_clean.geojson')

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FID        169 non-null    int32
#  1   LSOA21CD   169 non-null    object
#  2   LSOA21NM   169 non-null    object
#  3   LSOA21NMW  169 non-null    object
#  4   BNG_E      169 non-null    int32
#  5   BNG_N      169 non-null    int32
#  6   LAT        169 non-null    float64
#  7   LONG       169 non-null    float64
#  8   GlobalID   169 non-null    object
#  9   geometry   169 non-null    geometry
# dtypes: float64(2), geometry(1), int32(3), object(4)
# memory usage: 11.4+ KB

# %%
df.head()
# Out:
#     FID   LSOA21CD            LSOA21NM LSOA21NMW   BNG_E   BNG_N       LAT  \
# 0  3996  E01004198  Tower Hamlets 002B            535012  183130  51.53094
# 1  3997  E01004199  Tower Hamlets 002C            534754  183031  51.53012
# 2  3998  E01004200  Tower Hamlets 005A            534519  183093  51.53073
# 3  3999  E01004201  Tower Hamlets 002D            535390  183327  51.53262
# 4  4000  E01004202  Tower Hamlets 005B            534615  183389  51.53337
#
#       LONG                              GlobalID  \
# 0 -0.05496  d2c00273-5576-4419-b512-f44a7bead29a
# 1 -0.05872  f2febfb4-cc4b-442a-bde5-026947a7b905
# 2 -0.06208  3880fc11-1461-441d-a8a1-c2ee45824e18
# 3 -0.04944  1c69e8b2-1fcf-40d4-b69b-8f9f1b577e29
# 4 -0.06058  fc7f8670-271a-42cd-8eee-86bd2262ced2
#
#                                             geometry
# 0  POLYGON ((-0.05219 51.53033, -0.05383 51.5299,...
# 1  POLYGON ((-0.05726 51.53115, -0.05779 51.52798...
# 2  POLYGON ((-0.05973 51.53202, -0.05989 51.52968...
# ...
